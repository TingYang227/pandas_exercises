# %% [markdown]
# ### Import libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### N.B. A new cell in Jupyter Notebook starts a new figure.

# %% [markdown]
# ### 0. 基本的画图流程

# %%
# 1. Prepare Data
x = [10, 20, 70]
labels = ['Apple', 'Orange', 'Peach']

# 2. Cretate Plot

# A convenient way to create  a new figure and 
# returns a NumPy array containing the created 
# subplot objects
fig, axes = plt.subplots()
# select a subplot using axes[i, j]

# 3. Plot and customise the plot
axes.pie(x, startangle=90, labels=labels, autopct='%1.1f%%')

# 4. Save plot
plt.savefig('fig1.jpg', dpi=400, bbox_inches='tight')

# 5. Show plot
plt.show()

# %%
# A not so convenient way to create plot
# ======================================
# Create a new blank figure
fig = plt.figure()
# You can't make a plot with an black figure
# you have to create one or more subplots using add_subplot
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

# %% [markdown]
# ### 1. Pie
# Some useful parameters:
# 1. **explode** 决定每片饼向外offset移动的程度
# 2. labels
# 3. startangle 饼图默认从 positive x轴开始，逆时针旋转

# %% [markdown]
# ### 1.1 Basic pie chart

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
explode = [0, 0, 0.1, 0]  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ### 2. Labeling a pie and a donut

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]
explode = [0, 0, 0, 0]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"), explode=explode)

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()
